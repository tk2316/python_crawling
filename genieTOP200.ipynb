# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
# 타겟 사이트 주소 만들기
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=1 =>   1 ~  50
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=2 =>  51 ~ 100
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=3 => 101 ~ 150
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=4 => 151 ~ 200
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg='
for i in range(1, 5):
    # targetSite = url + str(i)
    targetSite = '{}{}'.format(url, i)
    print(targetSite)
# Out:
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=1
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=2
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=3
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=4

# %%
# 노래 제목 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg='
header = {"User-agent": "Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko"}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    # print(request)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    # print(soup)
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    # print(titles)
    # print(len(titles))
    
    for i in range(len(titles)):
        # print('{0:3d}위 {1}'.format(i + 1, titles[i].text.strip())) # 사용가능
        # print('{0:3d}위 {1}'.format(i + 1, titles[i].text.split('\n')[-1].strip())) # 사용가능
        print('{0:3d}위 {1}'.format(i + 1, titles[i].text.strip().split('\n')[0])) # 사용가능
# Out:
#   1위 Stay
#   2위 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
#   3위 신호등
#   4위 OHAYO MY NIGHT
#   5위 Queendom
#   6위 Next Level
#   7위 고백
#   8위 바라만 본다
#   9위 색안경 (STEREOTYPE)
#  10위 낙하 (With 아이유)
#  11위 Bad Habits
#  12위 DUMB DUMB
#  13위 Weekend
#  14위 Permission to Dance
#  15위 비가 오는 날엔 (2021)
#  16위 비와 당신
#  17위 좋아좋아
#  18위 Butter
#  19위 다정히 내 이름을 부르면
#  20위 Peaches (Feat. Daniel Caesar & Giveon)
#  21위 이제 나만 믿어요
#  22위 헤픈 우연
#  23위 Dynamite
#  24위 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  25위 다시 사랑한다면 (김필 Ver.)
#  26위 별빛 같은 나의 사랑아
#  27위 HERO
#  28위 고백
#  29위 그대라는 사치
#  30위 라일락
#  31위 롤린 (Rollin')
#  32위 끝사랑
#  33위 하루만 더
#  34위 Celebrity
#  35위 Dun Dun Dance
#  36위 Bk Love
#  37위 잊었니
#  38위 Savage Love (Laxed - Siren Beat) (BTS Remix)
#  39위 ASAP
#  40위 미워요
#  41위 사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)
#  42위 사랑의 아픔 딛고
#  43위 치맛바람 (Chi Mat Ba Ram)
#  44위 계단말고 엘리베이터
#  45위 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  46위 Alcohol-Free
#  47위 밤하늘의 별을 (2020)
#  48위 소리꾼
#  49위 Off My Face
#  50위 사진을 보다가

# %%
# 아티스트 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg='
header = {"User-agent": "Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko"}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')

    artists = soup.findAll('a', {'class', 'artist ellipsis'})
    # print(artists)
    # print(len(artists))
    
    for i in range(5, len(artists)):
        # print('{0:3d}위 {1}'.format(i - 4, artists[i].text.strip())) # 사용가능
        # print('{0:3d}위 {1}'.format(i - 4, artists[i].text.split('\n')[0])) # 사용가능
        print('{0:3d}위 {1}'.format(i - 4, artists[i].text.strip().split('\n')[0])) # 사용가능
# Out:
#   1위 The Kid LAROI & Justin Bieber
#   2위 케이윌 (K.Will)
#   3위 이무진
#   4위 디핵 (D-Hack) & PATEKO
#   5위 Red Velvet (레드벨벳)
#   6위 aespa
#   7위 멜로망스 (MeloMance)
#   8위 MSG워너비 (M.O.M)
#   9위 STAYC (스테이씨)
#  10위 AKMU (악뮤)
#  11위 Ed Sheeran
#  12위 전소미
#  13위 태연 (TAEYEON)
#  14위 방탄소년단
#  15위 헤이즈 (Heize)
#  16위 이무진
#  17위 조정석
#  18위 방탄소년단
#  19위 경서예지 & 전건호
#  20위 Justin Bieber
#  21위 임영웅
#  22위 헤이즈 (Heize)
#  23위 방탄소년단
#  24위 에픽하이 (EPIK HIGH)
#  25위 임영웅
#  26위 임영웅
#  27위 임영웅
#  28위 10CM
#  29위 임영웅
#  30위 아이유 (IU)
#  31위 브레이브걸스 (Brave girls)
#  32위 임영웅
#  33위 빅마마 (Big Mama)
#  34위 아이유 (IU)
#  35위 오마이걸 (OH MY GIRL)
#  36위 임영웅
#  37위 임영웅
#  38위 Jawsh 685 & Jason Derulo & 방탄소년단
#  39위 STAYC (스테이씨)
#  40위 임영웅
#  41위 호미들
#  42위 임영웅
#  43위 브레이브걸스 (Brave girls)
#  44위 임영웅
#  45위 방탄소년단
#  46위 TWICE (트와이스)
#  47위 경서
#  48위 Stray Kids (스트레이 키즈)
#  49위 Justin Bieber
#  50위 다비치

# %%
# 크롤링한 데이터를 리스트에 저장한다.
genie = [] # 200곡의 정보를 기억할 빈 리스트를 선언한다.
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg='
header = {"User-agent": "Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko"}
for i in range(1, 5):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')

    titles = soup.findAll('a', {'class': 'title ellipsis'})
    artists = soup.findAll('a', {'class', 'artist ellipsis'})
    
    for j in range(50):
        genie.append(
            (artists[j + 5].text.strip().split('\n')[0], titles[j].text.strip().split('\n')[0])
        )
# print(len(genie))
print(genie)
# Out:
# [('The Kid LAROI & Justin Bieber', 'Stay'), ('케이윌 (K.Will)', '시간을 거슬러 (낮에 뜨는 달 X 케이윌)'), ('이무진', '신호등'), ('디핵 (D-Hack) & PATEKO', 'OHAYO MY NIGHT'), ('Red Velvet (레드벨벳)', 'Queendom'), ('aespa', 'Next Level'), ('멜로망스 (MeloMance)', '고백'), ('MSG워너비 (M.O.M)', '바라만 본다'), ('STAYC (스테이씨)', '색안경 (STEREOTYPE)'), ('AKMU (악뮤)', '낙하 (With 아이유)'), ('Ed Sheeran', 'Bad Habits'), ('전소미', 'DUMB DUMB'), ('태연 (TAEYEON)', 'Weekend'), ('방탄소년단', 'Permission to Dance'), ('헤이즈 (Heize)', '비가 오는 날엔 (2021)'), ('이무진', '비와 당신'), ('조정석', '좋아좋아'), ('방탄소년단', 'Butter'), ('경서예지 & 전건호', '다정히 내 이름을 부르면'), ('Justin Bieber', 'Peaches (Feat. Daniel Caesar & Giveon)'), ('임영웅', '이제 나만 믿어요'), ('헤이즈 (Heize)', '헤픈 우연'), ('방탄소년단', 'Dynamite'), ('에픽하이 (EPIK HIGH)', '비 오는 날 듣기 좋은 노래 (Feat. Colde)'), ('임영웅', '다시 사랑한다면 (김필 Ver.)'), ('임영웅', '별빛 같은 나의 사랑아'), ('임영웅', 'HERO'), ('10CM', '고백'), ('임영웅', '그대라는 사치'), ('아이유 (IU)', '라일락'), ('브레이브걸스 (Brave girls)', "롤린 (Rollin')"), ('임영웅', '끝사랑'), ('빅마마 (Big Mama)', '하루만 더'), ('아이유 (IU)', 'Cel
# ...

# %%
print('{} 현재'.format(dt.now()))
for i in range(200):
    print('{0:3d}위 {1} - {2}'.format(i + 1, genie[i][0], genie[i][1]))
# Out:
# 2021-09-06 22:39:08.354407 현재
#   1위 The Kid LAROI & Justin Bieber - Stay
#   2위 케이윌 (K.Will) - 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
#   3위 이무진 - 신호등
#   4위 디핵 (D-Hack) & PATEKO - OHAYO MY NIGHT
#   5위 Red Velvet (레드벨벳) - Queendom
#   6위 aespa - Next Level
#   7위 멜로망스 (MeloMance) - 고백
#   8위 MSG워너비 (M.O.M) - 바라만 본다
#   9위 STAYC (스테이씨) - 색안경 (STEREOTYPE)
#  10위 AKMU (악뮤) - 낙하 (With 아이유)
#  11위 Ed Sheeran - Bad Habits
#  12위 전소미 - DUMB DUMB
#  13위 태연 (TAEYEON) - Weekend
#  14위 방탄소년단 - Permission to Dance
#  15위 헤이즈 (Heize) - 비가 오는 날엔 (2021)
#  16위 이무진 - 비와 당신
#  17위 조정석 - 좋아좋아
#  18위 방탄소년단 - Butter
#  19위 경서예지 & 전건호 - 다정히 내 이름을 부르면
#  20위 Justin Bieber - Peaches (Feat. Daniel Caesar & Giveon)
#  21위 임영웅 - 이제 나만 믿어요
#  22위 헤이즈 (Heize) - 헤픈 우연
#  23위 방탄소년단 - Dynamite
#  24위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  25위 임영웅 - 다시 사랑한다면 (김필 Ver.)
#  26위 임영웅 - 별빛 같은 나의 사랑아
#  27위 임영웅 - HERO
#  28위 10CM - 고백
#  29위 임영웅 - 그대라는 사치
#  30위 아이유 (IU) - 라일락
#  31위 브레이브걸스 (Brave girls) - 롤린 (Rollin')
# ...

# %%
# 크롤링한 결과를 텍스트 파일로 저장한다.
file = open('./output/genieTop200.txt', 'w', -1, 'UTF-8')# 위의 문장처럼 실행했는데 cp949 어쩌고 하면서 에러가 발생되면 open() 함수를 아래와 같이 수정한다.
# file = open('./output/genieTOP200.txt', 'w', -1, 'UTF-8')
file.write('{} 현재 Genie 뮤직 실시간 TOP 200\n'.format(dt.now()))
for i in range(200):
    file.write('{0:3d}위 {1} - {2}\n'.format(i + 1, genie[i][0], genie[i][1]))          
file.close()
print('genieTOP200.txt 파일로 쓰기 완료')
# Out:
# genieTOP200.txt 파일로 쓰기 완료

# %%
try:
    file = open('./output/genieTop200.txt', 'r', -1, 'UTF-8')# 위의 문장처럼 실행했는데 cp949 어쩌고 하면서 에러가 발생되면 open() 함수를 아래와 같이 수정한다.
    lines = file.readlines()
    for line in lines:
        print(line.strip())
    file.close()
    print('genieTOP200.txt 파일에서 읽기 완료')
except FileNotFoundError:
    print('디스크에 genieTOP200.txt 파일이 없습니다.')
# Out:
# 2021-09-06 22:41:10.057698 현재 Genie 뮤직 실시간 TOP 200
# 1위 The Kid LAROI & Justin Bieber - Stay
# 2위 케이윌 (K.Will) - 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
# 3위 이무진 - 신호등
# 4위 디핵 (D-Hack) & PATEKO - OHAYO MY NIGHT
# 5위 Red Velvet (레드벨벳) - Queendom
# 6위 aespa - Next Level
# 7위 멜로망스 (MeloMance) - 고백
# 8위 MSG워너비 (M.O.M) - 바라만 본다
# 9위 STAYC (스테이씨) - 색안경 (STEREOTYPE)
# 10위 AKMU (악뮤) - 낙하 (With 아이유)
# 11위 Ed Sheeran - Bad Habits
# 12위 전소미 - DUMB DUMB
# 13위 태연 (TAEYEON) - Weekend
# 14위 방탄소년단 - Permission to Dance
# 15위 헤이즈 (Heize) - 비가 오는 날엔 (2021)
# 16위 이무진 - 비와 당신
# 17위 조정석 - 좋아좋아
# 18위 방탄소년단 - Butter
# 19위 경서예지 & 전건호 - 다정히 내 이름을 부르면
# 20위 Justin Bieber - Peaches (Feat. Daniel Caesar & Giveon)
# 21위 임영웅 - 이제 나만 믿어요
# 22위 헤이즈 (Heize) - 헤픈 우연
# 23위 방탄소년단 - Dynamite
# 24위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 25위 임영웅 - 다시 사랑한다면 (김필 Ver.)
# 26위 임영웅 - 별빛 같은 나의 사랑아
# 27위 임영웅 - HERO
# 28위 10CM - 고백
# 29위 임영웅 - 그대라는 사치
# 30위 아이유 (IU) - 라일락
# 31위 브레이브걸스 (Brave girls) - 롤린 (Rollin')
# 32위 임영웅 - 끝사랑
# ...
